# %%
# Import
from pyRSD import pygcl
import matplotlib.pyplot as plt

# from nbodykit.lab import *
import numpy as np
from pyRSD.rsdfit.data import PowerMeasurements
from pyRSD.rsdfit import FittingDriver

plt.rcParams['figure.figsize']        = 6., 4.
# plt.rcParams['figure.subplot.left']   = 0.125
# plt.rcParams['figure.subplot.right']  = 0.9
# plt.rcParams['figure.subplot.bottom'] = 0.125
# plt.rcParams['figure.subplot.top']    = 0.9
plt.rcParams['axes.labelsize']        = 18
plt.rcParams['axes.titlesize']        = 18
plt.rcParams['xtick.top']             = True
plt.rcParams['xtick.bottom']          = True
plt.rcParams['ytick.left']            = True
plt.rcParams['ytick.right']           = True
plt.rcParams['xtick.direction']       = 'in'
plt.rcParams['ytick.direction']       = 'in'
plt.rcParams['xtick.labelsize']       = 18
plt.rcParams['ytick.labelsize']       = 18
plt.rcParams['xtick.major.pad']       = 6.
plt.rcParams['xtick.minor.pad']       = 6.
plt.rcParams['ytick.major.pad']       = 6.
plt.rcParams['ytick.minor.pad']       = 6.
plt.rcParams['xtick.major.size']      = 6. # major tick size in points
plt.rcParams['xtick.minor.size']      = 3. # minor tick size in points
plt.rcParams['ytick.major.size']      = 6. # major tick size in points
plt.rcParams['ytick.minor.size']      = 3. # minor tick size in points
plt.rcParams['text.usetex']           = False
plt.rcParams['font.family']           = 'serif'
#plt.rcParams['font.serif']            = 'Computer Modern Roman Bold'
plt.rcParams['font.size']             = 18

# %%
# Result file path
RESULTD = '2022-02-22_nlopt_59i_chain0__1.npz'
# RESULTD = '2022-03-18_nlopt_146i_chain0__1.npz'

# Specify model + result file paths
d = FittingDriver.from_directory('/pscratch/sd/g/gstein/machine_learning/pae/rsd_project/pyrsd/z1_NGC_6S', model_file='/pscratch/sd/g/gstein/machine_learning/pae/rsd_project/pyrsd/z1_NGC_6S/Run1_Model_LOWZ_N.npy', results_file=RESULTD)
d.set_fit_results()

# P(k) best-fit model
model_d = d.theory.model

# %%
cosmo = d.theory.model.cosmo

# %%
# Set the transfer function as Eisenstein & Hu + no wiggle
cosmo.SetTransferFunction(tf=pygcl.transfers.EH_NoWiggle)

# %%
# Load best-fit (unconvolved) P_ell's
k_pole_highk = np.logspace(-3, 0, 1000)
P0_highk_d = d.theory.model.poles(k_pole_highk , 0)
P2_highk_d = d.theory.model.poles(k_pole_highk , 2)
P4_highk_d = d.theory.model.poles(k_pole_highk , 4)

# %%
# Load the data
data = np.loadtxt('../data/Pell_avgmock1000_z1_NGC_6S.dat')
k_N1 = data[0:76,0]
P0_dat = data[0:len(k_N1),1]
P2_dat = data[len(k_N1):2*len(k_N1),1]
P4_dat = data[2*len(k_N1):3*len(k_N1),1]

# Load the covariance (reduced by np.sqrt(1000) - avg of 1000 sims)
from pyRSD.rsdfit.data import PoleCovarianceMatrix
cov_analytic_N1 = PoleCovarianceMatrix.from_plaintext('../data/reducebysq1000_data_covariance_PATCHY_z1NGC.dat')
err_P0_dat = np.sqrt(cov_analytic_N1[0:len(k_N1), 0:len(k_N1)].diagonal())
err_P2_dat = np.sqrt(cov_analytic_N1[len(k_N1):2*len(k_N1), len(k_N1):2*len(k_N1)].diagonal())
err_P4_dat = np.sqrt(cov_analytic_N1[2*len(k_N1):3*len(k_N1), 2*len(k_N1):3*len(k_N1)].diagonal())

# %%
plt.figure(figsize=(10,7))

# Plot the data
plt.errorbar(k_N1, k_N1*P0_dat, yerr = k_N1*err_P0_dat, fmt='.', mfc='None', mec='royalblue', ecolor = 'royalblue', capsize = 3.0, label = 'P_0', zorder=10)
plt.errorbar(k_N1, k_N1*P2_dat, yerr = k_N1*err_P2_dat, fmt='.', mfc='None', mec='crimson', ecolor = 'crimson', capsize = 3.0, label = 'P_0', zorder=10)
plt.errorbar(k_N1, k_N1*P4_dat, yerr = k_N1*err_P4_dat, fmt='.', mfc='None', mec='seagreen', ecolor = 'seagreen', capsize = 3.0, label = 'P_0', zorder=10)

# Plot the unconvolved theory
plt.plot(k_pole_highk, k_pole_highk*P0_highk_d[:,0], 'k-')
plt.plot(k_pole_highk, k_pole_highk*P2_highk_d[:,0], 'k-')
plt.plot(k_pole_highk, k_pole_highk*P4_highk_d[:,0], 'k-')

# Plot the convolved theory
# plt.plot(k_pole_highk, k_pole_highk*Pell_convolved[:,0], 'k--')
# plt.plot(k_pole_highk, k_pole_highk*Pell_convolved[:,1], 'k--')
# plt.plot(k_pole_highk, k_pole_highk*Pell_convolved[:,2], 'k--')

plt.xlim(0, 0.4)
# Out:
# (0.0, 0.4)

# %%
# Linear Power using the fitted cosmology (using Eisenstein & Hu no wiggle transfer function)
cosmo_d = d.theory.model.cosmo
cosmo_d_clone = cosmo_d.clone(tf=pygcl.transfers.EH_NoWiggle)
linpower_z1 = pygcl.LinearPS(cosmo_d_clone, d.model.z)
linpower_z1.SetSigma8AtZ(d.theory.fit_params['sigma8_z'].value)

b = d.theory.fit_params['b1'].value
f = d.theory.fit_params['f'].value

# %%
# Plot k vs. P_l

plt.figure(figsize=(10,7))
plt.loglog(k_pole_highk, np.array(P0_highk_d[:,0]), '-', color = 'royalblue', lw=2.5)
plt.loglog(k_pole_highk, ((b**2+2*b*f/3+(1/5)*f**2)*linpower_z1(k_pole_highk)), '--', color = 'black', lw=2.5)

plt.loglog(k_pole_highk, np.array(P2_highk_d[:,0]), '-', color = 'crimson', lw=2.5)
plt.plot(k_pole_highk, (4*b*f/3+(4/7)*f**2)*linpower_z1(k_pole_highk), '--', color = 'black', lw=2.5)

plt.loglog(k_pole_highk, np.array(P4_highk_d[:,0]), '-', color = 'seagreen', lw=2.5)
plt.plot(k_pole_highk, (8/35*f**2)*linpower_z1(k_pole_highk), '--', color = 'black', lw=2.5)

plt.xlim(1e-3, 0.4)
plt.ylim(1e2, 1e5)
plt.ylabel('$P_l$', fontsize=20)
plt.xlabel('k', fontsize=17)
# Out:
# Text(0.5, 0, 'k')

# %%
# Plot Nonlinear/Linear ratio

plt.figure(figsize=(10,7))
plt.plot(k_pole_highk, np.array(P0_highk_d[:,0])/((b**2+2*b*f/3+(1/5)*f**2)*linpower_z1(k_pole_highk)), '-', color = 'royalblue', lw=2.5)
plt.plot(k_pole_highk, np.array(P2_highk_d[:,0])/((4*b*f/3+(4/7)*f**2)*linpower_z1(k_pole_highk)), '-', color = 'crimson', lw=2.5)
plt.plot(k_pole_highk, np.array(P4_highk_d[:,0])/((8/35*f**2)*linpower_z1(k_pole_highk)), '-', color = 'seagreen', lw=2.5)

xx = np.linspace(0, 0.5, 100)
plt.plot(xx, np.ones(100), 'k--')
plt.semilogx(k_pole_highk, np.ones(1000))
plt.xlim(1e-3, 0.4)
plt.ylim(0, 2)
plt.ylabel('NONLIN/$P^{\mathrm{lin}}$', fontsize=20)
plt.xlabel('k', fontsize=17)
# Out:
# Text(0.5, 0, 'k')

# %%
k = k_N1
cov = d.data.covariance_matrix.values
cov_inv = d.data.covariance_matrix.inverse
sigma = np.sqrt(cov.diagonal()).reshape(3, -1)
np.savez("../data/p0-p2-p4_cov.npz",
         k=k,
         cov=cov,
         cov_inv=cov_inv,
         sigma=sigma,
        )
print(cov)
plt.imshow(cov)

plt.figure()
for i in range(sigma.shape[0]):
    plt.semilogy(k, sigma[i], label=f"{i}")
plt.legend()
# Out:
# [[ 2.95996125e+04  6.30258280e+03  1.49389546e+03 ... -4.76862129e+00
#    9.72438914e+00  1.12069812e+01]
#  [ 6.30258280e+03  1.62962261e+04  3.08039300e+03 ... -8.14856803e+00
#    3.48529473e+00 -6.08203076e+00]
#  [ 1.49389546e+03  3.08039300e+03  9.44889479e+03 ... -5.43268548e+00
#    2.39844225e+00  1.27800410e+00]
#  ...
#  [-4.76862129e+00 -8.14856803e+00 -5.43268548e+00 ...  3.86694799e+00
#    1.71570278e+00  4.41016496e-01]
#  [ 9.72438914e+00  3.48529473e+00  2.39844225e+00 ...  1.71570278e+00
#    3.75607849e+00  1.78428935e+00]
#  [ 1.12069812e+01 -6.08203076e+00  1.27800410e+00 ...  4.41016496e-01
#    1.78428935e+00  3.42392133e+00]]

# %%
# P_data = np.array([P0_dat, P2_dat, P4_dat]).flatten()
# P_theory = np.array([Pell_convolved[:,0], Pell_convolved[:,1], Pell_convolved[:,2]]).flatten()
# diff = P_theory-P_data
# lnlike = -0.5*np.dot(diff, np.dot(d.data.covariance_matrix.inverse, diff))

# %%
d.theory.fit_params
# Out:
# <ParameterSet (size: 35)>

# %%
# Get params and their priors and put in dictionary
params = d.theory.fit_params
# use all varied params
names  = [k for k in params if params[k].vary] 

# names = ['sigma8_z', 'f', 'b1_cA']
values = [params[i].value for i in names] 
priors = [params[i].prior for i in names] 

param_priors = {}
for i in range(len(names)):
    
    name = names[i]
    value = values[i]
    prior = priors[i]

    try:
        prior_type = 'normal'
        prior_vals = [prior.mu, prior.sigma]
    except:
        prior_type = 'uniform'
        prior_vals = [prior.lower, prior.upper]
        
    param_priors[name] = {
        'value': value,
        'prior': prior_type,
        'prior_vals': prior_vals,
    }
    
param_priors['sigma8_z']['prior_vals'][0] = 0.5
param_priors
# Out:
# {'Nsat_mult': {'value': 2.4040909618597026,
#   'prior': 'normal',
#   'prior_vals': [2.4, 0.2]},
#  'b1_cA': {'value': 1.5657029077250786,
#   'prior': 'uniform',
#   'prior_vals': [1.2, 2.5]},
#  'f': {'value': 0.6527528891436477,
#   'prior': 'uniform',
#   'prior_vals': [0.6, 1.0]},
#  'f1h_sBsB': {'value': 3.9238303370686025,
#   'prior': 'normal',
#   'prior_vals': [4.0, 1.0]},
#  'fs': {'value': 0.051620638641754035,
#   'prior': 'uniform',
#   'prior_vals': [0.0, 0.25]},
#  'fsB': {'value': 0.979723456922603,
#   'prior': 'uniform',
#   'prior_vals': [0.0, 1.0]},
#  'gamma_b1sA': {'value': 1.4586847999857098,
#   'prior': 'normal',
#   'prior_vals': [1.45, 0.3]},
#  'gamma_b1sB': {'value': 2.10462268759816,
#   'prior': 'normal',
#   'prior_vals': [2.05, 0.3]},
#  'sigma8_z': {'value': 0.7381751882968806,
#   'prior': 'uniform',
#   'prior_vals': [0.5, 0.9]},
#  'sigma_c': {'value': 1.4745426397353925,
#   'prior': 'uniform',
#   'prior_vals': [0.0, 3.0]},
#  'sigma_sA': {'value': 1.2742081601473432,
#   'prior': 'uniform',
#   'prior_vals': [0.0, 18.0]}}

# %%
names
# Out:
# ['Nsat_mult',
#  'b1_cA',
#  'f',
#  'f1h_sBsB',
#  'fs',
#  'fsB',
#  'gamma_b1sA',
#  'gamma_b1sB',
#  'sigma8_z',
#  'sigma_c',
#  'sigma_sA']

# %%
# Sample new model parameters from prior
def sample_params_from_priors(params: dict):
    """
    params is a dictionary with parameter name as key, and prior/prior_vals as items
    """
    sample = {}
    for k in params:
        if params[k]['prior'] == 'uniform':
            lower, upper = params[k]['prior_vals']
            val = np.random.uniform(lower, upper)
        if params[k]['prior'] == 'normal':
            mu, sig = params[k]['prior_vals']
            val = np.random.normal(mu, sig)
                       
        sample[k] = val
        
    return sample

def update_model_params(sample, model):
    for param in sample:

        if param =='Nsat_mult': 
            model.Nsat_mult = sample[param]

        if param == 'b1_cA': 
            model.b1_cA = sample[param]

        if param == 'f': 
            model.f = sample[param]

        if param == 'f1h_sBsB':
            model.f1h_sBsB = sample[param]

        if param == 'fs':
            model.fs = sample[param]

        if param == 'fsB': 
            model.fsB = sample[param]

        if param == 'gamma_b1sA': 
            model.gamma_b1sA = sample[param]

        if param == 'gamma_b1sB': 
            model.gamma_b1sB = sample[param]

        if param == 'sigma8_z': 
            model.sigma8_z = sample[param]

        if param == 'sigma_c': 
            model.sigma_c = sample[param]

        if param == 'sigma_sA': 
            model.sigma_sA = sample[param]

    # return model

def update_fitted_model_params(sample, model):
    for param in sample:
        model[param].value = sample[param]

  
sample_params_from_priors(param_priors)
# Out:
# {'Nsat_mult': 2.683616266291129,
#  'b1_cA': 1.3435061330203095,
#  'f': 0.7658119584579071,
#  'f1h_sBsB': 4.244487197533557,
#  'fs': 0.2399438053805948,
#  'fsB': 0.23849994824691034,
#  'gamma_b1sA': 1.79821568675648,
#  'gamma_b1sB': 2.1854179249092986,
#  'sigma8_z': 0.7064160947757001,
#  'sigma_c': 2.532975216869194,
#  'sigma_sA': 15.621097978347578}

# %%
# d.theory.model.cosmo.f_z
d.theory.model.b1
# Out:
# 2.0

# %%
import time


nsamples = 10
kbin_data = np.load("../data/p0-p2-p4_cov.npz")
        #  k=k,
        #  cov=cov,
        #  cov_inv=cov_inv,
        #  sigma=sigma,
        # )
print(kbin_data.files)        
k_pole_highk = kbin_data['k']
P_err = kbin_data['sigma']

nk = k_pole_highk.shape[0]
kmin = k_pole_highk[0]
kmax = k_pole_highk[-1]

fig, ax = plt.subplots(1, 3, figsize=(16,4))
np.random.seed(13579)

for i in range(nsamples):
    
    sample = sample_params_from_priors(param_priors)
    update_fitted_model_params(sample, d.theory.fit_params)
    update_model_params(sample, model_d)
    
    model_d.b1 = (1 - model_d.fs)*model_d.b1_c + model_d.fs*model_d.b1_s
    d.theory.fit_params['b1'].value = (1 - model_d.fs)*model_d.b1_c + model_d.fs*model_d.b1_s

    # b = d.theory.fit_params['b1'].value
    # f = d.theory.fit_params['f'].value
     
    b = model_d.b1
    f = model_d.f    
    
    linpower_z1.SetSigma8AtZ(model_d.sigma8_z)

    # linpower_z1.SetSigma8AtZ(d.theory.fit_params['sigma8_z'].value)

    # Re-load best-fit (unconvolved) P_ell's
    P0_highk_d = d.theory.model.poles(k_pole_highk, 0)
    P2_highk_d = d.theory.model.poles(k_pole_highk, 2)
    P4_highk_d = d.theory.model.poles(k_pole_highk, 4)

    lin = linpower_z1(k_pole_highk)
    lin0 = (b**2 + 2*b*f/3 + (1/5)*f**2)*lin
    lin2 = (4*b*f/3 + (4/7)*f**2)*lin  
    lin4 = (8/35*f**2)*lin  

    pk0_r = np.array(P0_highk_d[:,0])/lin0
    pk2_r = np.array(P2_highk_d[:,0])/lin2
    pk4_r = np.array(P4_highk_d[:,0])/lin4
    
    pk0_r_sig = np.abs(pk0_r) * np.sqrt( (P_err[0]/np.array(P0_highk_d[:,0]))**2 + (P_err[0]/lin0)**2)
    pk2_r_sig = np.abs(pk2_r) * np.sqrt( (P_err[1]/np.array(P2_highk_d[:,0]))**2 + (P_err[1]/lin2)**2)
    pk4_r_sig = np.abs(pk4_r) * np.sqrt( (P_err[2]/np.array(P4_highk_d[:,0]))**2 + (P_err[2]/lin4)**2)
    
    ax[0].plot(
        k_pole_highk,
        pk0_r,
        color=f'C{i%10}',
        lw=2.5,
        label=', '.join([f'{k}={sample[k]:0.2f}' for k in sample])
    )
    ax[0].fill_between(
        k_pole_highk,
        pk0_r - pk0_r_sig,
        pk0_r + pk0_r_sig,
        color=f'C{i%10}',
        alpha = 0.1
    )   
 
    ax[1].plot(
        k_pole_highk,
        pk2_r,
        color=f'C{i%10}',
        lw=2.5,
        label=', '.join([f'{k}={sample[k]:0.2f}' for k in sample])
    )
    ax[1].fill_between(
        k_pole_highk,
        pk2_r - pk2_r_sig,
        pk2_r + pk2_r_sig,
        color=f'C{i%10}',
        alpha = 0.1
    )   
    ax[2].plot(
        k_pole_highk,
        pk4_r,
        color=f'C{i%10}',
        lw=2.5,
        label=', '.join([f'{k}={sample[k]:0.2f}' for k in sample])
    )
    ax[2].fill_between(
        k_pole_highk,
        pk4_r - pk4_r_sig,
        pk4_r + pk4_r_sig,
        color=f'C{i%10}',
        alpha = 0.1
    )   
   
xx = np.linspace(kmin, kmax, 100)
plt.plot(xx, np.ones(100), 'k--')
for axi in ax:
    axi.semilogx(k_pole_highk, np.ones(nk))
    axi.set_xlim(kmin, kmax)
    axi.set_xlabel('k', fontsize=17)

    # axi.set_ylim(0, 10)
    
ax[0].set_ylabel('$P^{\mathrm{non-lin}}$/$P^{\mathrm{lin}}$', fontsize=20)

# plt.legend(loc='upper center')
# Out:
# ['k', 'cov', 'cov_inv', 'sigma']
# Text(0, 0.5, '$P^{\\mathrm{non-lin}}$/$P^{\\mathrm{lin}}$')

# %% [markdown]
# # Check how varying model params changes pk_r

# %%
model_param_names = np.array(['Nsat_mult', 'b1_cA', 'f', 'f1h_sBsB', 'fs', 'fsB', 'gamma_b1sA', 'gamma_b1sB', 'sigma8_z', 'sigma_c', 'sigma_sA'], dtype='<U10')

model_params_mean = np.array([2.4 , 1.85, 0.8, 4., 0.125, 0.5, 1.45, 2.05, 0.7, 1.5, 9.0 ])
param_min = np.array([1.8, 1.2, 0.6, 1., 0., 0., 0.55, 1.15, 0.5, 0., 0. ], dtype=np.float32)
param_max = np.array([3.0, 2.5, 1., 7., 0.25, 1., 2.35, 2.95, 0.9, 3., 18. ], dtype=np.float32)

nplt = 10
multipole_order = 3
cmap = plt.cm.jet

nx = model_params_mean.shape[0]
ny = max(multipole_order, 2)

fig, ax = plt.subplots(ny, nx, figsize=(3*nx,3*ny), sharex='col', sharey='row')
plt.subplots_adjust(hspace=0.01, wspace=0.01)
for iparam in range(model_params_mean.shape[0]):
    paramsi = np.tile(model_params_mean, (nplt, 1))

    param_val_vary = np.linspace(param_min[iparam], param_max[iparam], nplt)
    paramsi[:, iparam] = param_val_vary

    paramsi_print = paramsi.copy()

    for i in range(nplt):
        
        c = (param_val_vary[i] - param_min[iparam])/(param_max[iparam] - param_min[iparam])
        # print(param_val_vary[i], param_min[iparam], param_max[iparam], c)
        lab = f'{paramsi_print[i, iparam]:.2f}'

        p = {} # make param dictionary
        for ip, param in enumerate(model_param_names):
            p[param] = paramsi[i][ip]

        update_fitted_model_params(p, d.theory.fit_params)
        update_model_params(p, model_d)

        model_d.b1 = (1 - model_d.fs)*model_d.b1_c + model_d.fs*model_d.b1_s
        d.theory.fit_params['b1'].value = (1 - model_d.fs)*model_d.b1_c + model_d.fs*model_d.b1_s

        b = model_d.b1
        f = model_d.f    

        linpower_z1.SetSigma8AtZ(model_d.sigma8_z)

        # Linear spectra
        lin = linpower_z1(k)

        pk0_lin = (b**2+2*b*f/3+(1/5)*f**2)*lin
        pk2_lin = (4*b*f/3+(4/7)*f**2)*lin  
        pk4_lin = (8/35*f**2)*lin  


        # Non-linear spectra
        pk0_nonlin = np.array(d.theory.model.poles(k, 0)).flatten()
        pk2_nonlin = np.array(d.theory.model.poles(k, 2)).flatten()
        pk4_nonlin = np.array(d.theory.model.poles(k, 4)).flatten()

        # if i % print_every == 0:
        #     print(f"{ichunk}, {i}: time elapsed = {time.time() - tstart}")

        pk0_r = pk0_nonlin/pk0_lin
        pk2_r = pk2_nonlin/pk2_lin
        pk4_r = pk4_nonlin/pk4_lin

        ax[0, iparam].plot(k, pk0_r, color=cmap(c), ls='--', label=lab)
        ax[1, iparam].plot(k, pk2_r, color=cmap(c), ls='--')
        ax[2, iparam].plot(k, pk4_r, color=cmap(c), ls='--')

    ax[0, iparam].legend(loc='upper left', ncol=2, fontsize=10, columnspacing=0.5)
    # if iparam == 0:
   
    ax[0, iparam].set_title(model_param_names[iparam])
    ax[2, iparam].set_xlabel('k')
    
ax[0,0].set_ylabel(f"$P_0^{{non-lin}}/P_0^{{lin}}$")
ax[1,0].set_ylabel(f"$P_2^{{non-lin}}/P_2^{{lin}}$")
ax[2,0].set_ylabel(f"$P_4^{{non-lin}}/P_4^{{lin}}$")

#     ax[0].set_ylabel('$r=P^{non-lin}/P^{lin}$')
plt.savefig("../../figures/pk_vary_model_params_true.pdf", bbox_inches='tight')

# %%
list(sample.values()), list(sample.keys()),
# Out:
# ([2.34029880385561,
#   2.1828510407601445,
#   0.604445494999829,
#   3.553517542138473,
#   0.23117395577648567,
#   0.19671744631127397,
#   1.7679347324978885,
#   2.1008305733124755,
#   0.6091352683724125,
#   1.7326884380754486,
#   13.292287658268481],
#  ['Nsat_mult',
#   'b1_cA',
#   'f',
#   'f1h_sBsB',
#   'fs',
#   'fsB',
#   'gamma_b1sA',
#   'gamma_b1sB',
#   'sigma8_z',
#   'sigma_c',
#   'sigma_sA'])

# %% [markdown]
# # Make large sample and save to disk

# %%
from multiprocessing import Pool

import h5py
import time
import os
import math

nsamples = 1000000 #256000 #128000
chunksize = 100
print_every = 100

# Get k-bins
kbin_data = np.load("../data/p0-p2-p4_cov.npz")
k         = kbin_data['k'].astype(np.float32)
P_err     = kbin_data['sigma'].astype(np.float32)

nk   = k_pole_highk.shape[0]
kmin = k_pole_highk[0]
kmax = k_pole_highk[-1]

param_string = '-'.join(list(param_priors.keys())) 

nchunks = math.ceil(nsamples/chunksize)

def generate_chunk(ichunk):
    
    np.random.seed(ichunk)
    model_params = np.empty((chunksize, len(param_priors)), dtype=np.float32)

    pk0_lin    = np.empty((chunksize, nk), dtype=np.float32)
    pk2_lin    = np.empty((chunksize, nk), dtype=np.float32)
    pk4_lin    = np.empty((chunksize, nk), dtype=np.float32)
    pk0_nonlin = np.empty((chunksize, nk), dtype=np.float32)
    pk2_nonlin = np.empty((chunksize, nk), dtype=np.float32)
    pk4_nonlin = np.empty((chunksize, nk), dtype=np.float32)

    # pk0_r = np.empty((nsamples, nk), dtype=np.float32)
    # pk2_r = np.empty((nsamples, nk), dtype=np.float32)

    tstart = time.time()
    for i in range(chunksize):

        sample = sample_params_from_priors(param_priors)
        model_params[i] = list(sample.values())

        update_fitted_model_params(sample, d.theory.fit_params)
        update_model_params(sample, model_d)

        model_d.b1 = (1 - model_d.fs)*model_d.b1_c + model_d.fs*model_d.b1_s
        d.theory.fit_params['b1'].value = (1 - model_d.fs)*model_d.b1_c + model_d.fs*model_d.b1_s

        b = model_d.b1
        f = model_d.f    

        linpower_z1.SetSigma8AtZ(model_d.sigma8_z)

        # Linear spectra
        lin = linpower_z1(k)

        pk0_lin[i] = (b**2+2*b*f/3+(1/5)*f**2)*lin
        pk2_lin[i] = (4*b*f/3+(4/7)*f**2)*lin  
        pk4_lin[i] = (8/35*f**2)*lin  


        # Non-linear spectra
        pk0_nonlin[i] = np.array(d.theory.model.poles(k, 0)).flatten()
        pk2_nonlin[i] = np.array(d.theory.model.poles(k, 2)).flatten()
        pk4_nonlin[i] = np.array(d.theory.model.poles(k, 4)).flatten()

        # if i % print_every == 0:
        #     print(f"{ichunk}, {i}: time elapsed = {time.time() - tstart}")

    pk0_r = pk0_nonlin/pk0_lin
    pk2_r = pk2_nonlin/pk2_lin
    pk4_r = pk4_nonlin/pk4_lin

    pk0_r_sig = np.abs(pk0_r) * np.sqrt( (P_err[0]/pk0_lin)**2 + (P_err[0]/pk0_nonlin)**2)
    pk2_r_sig = np.abs(pk2_r) * np.sqrt( (P_err[1]/pk2_lin)**2 + (P_err[1]/pk2_nonlin)**2)
    pk4_r_sig = np.abs(pk4_r) * np.sqrt( (P_err[2]/pk4_lin)**2 + (P_err[2]/pk4_nonlin)**2)
    
    print(f"SAVING DATA {ichunk}")
    
    data_dir = '../../data/'
    # data_path = f'{data_dir}/powerspectra_{param_string}.h5'
    data_path = f'{data_dir}/powerspectra_11param_{ichunk*chunksize:06d}_{(ichunk+1)*chunksize:06d}.h5'

    try: 
        os.remove(data_path)
    except:
        print('file doesnt exist')

    with h5py.File(data_path, 'w') as f:
        f.create_dataset("k", data=k)    
        f.create_dataset("model_params", data=model_params)
        f.create_dataset("model_param_names", data=np.array(list(param_priors.keys())).astype('S'))
        
        f.create_dataset("pk0_sig", data=P_err[0])
        f.create_dataset("pk2_sig", data=P_err[1])
        f.create_dataset("pk4_sig", data=P_err[2])

        f.create_dataset("pk0_lin", data=pk0_lin)
        f.create_dataset("pk2_lin", data=pk2_lin)
        f.create_dataset("pk4_lin", data=pk4_lin)
        
        f.create_dataset("pk0_nonlin", data=pk0_nonlin)
        f.create_dataset("pk2_nonlin", data=pk2_nonlin)
        f.create_dataset("pk4_nonlin", data=pk4_nonlin)

        f.create_dataset("pk0_r", data=pk0_r)
        f.create_dataset("pk2_r", data=pk2_r)
        f.create_dataset("pk4_r", data=pk4_r)

        f.create_dataset("pk0_r_sig", data=pk0_r_sig)
        f.create_dataset("pk2_r_sig", data=pk2_r_sig)
        f.create_dataset("pk4_r_sig", data=pk4_r_sig)

pool = Pool(64)
# with pool:
pool.map(generate_chunk, range(2560, nchunks))
    
pool.close()
pool.join()
# Out:
# SAVING DATA 2650
# file doesnt exist
# SAVING DATA 3430
# file doesnt exist
# SAVING DATA 4270
# file doesnt exist
# SAVING DATA 3820
# file doesnt exist
# SAVING DATA 3760
# file doesnt exist
# SAVING DATA 3010
# file doesnt exist
# SAVING DATA 2890
# file doesnt exist
# SAVING DATA 2620
# file doesnt exist
# SAVING DATA 4390
# file doesnt exist
# SAVING DATA 3790
# file doesnt exist
# SAVING DATA 4300
# file doesnt exist
# SAVING DATA 3040
# file doesnt exist
# SAVING DATA 9129
# file doesnt exist
# SAVING DATA 9668
# file doesnt exist
# SAVING DATA 8829
# file doesnt exist
# SAVING DATA 8589
# file doesnt exist
# SAVING DATA 9219
# file doesnt exist
# SAVING DATA 9248
# file doesnt exist
# SAVING DATA 9309
# file doesnt exist
# SAVING DATA 9159
# file doesnt exist
# SAVING DATA 9489
# file doesnt exist
# SAVING DATA 9189
# file doesnt exist
# SAVING DATA 9938
# file doesnt exist
# SAVING DATA 8649
# file doesnt exist
# SAVING DATA 9429
# file doesnt exist
# SAVING DATA 8739
# file doesnt exist
# SAVING DATA 9339
# file doesnt exist
# SAVING DATA 9789
# file doesnt exist
# SAVING DATA 9639
# file doesnt exist
# SAVING DATA 9579
# file doesnt exist
# SAVING DATA 8409
# file doesnt exist
# SAVING DATA 8919
# file doesnt exist
# SAVING DATA 9399
# file doesnt exist
# SAVING DATA 8949
# file doesnt exist
# SAVING DATA 9369
# file doesnt exist
# SAVING DATA 9699
# file doesnt exist
# SAVING DATA 9549
# file doesnt exist
# SAVING DATA 9069
# file doesnt exist
# SAVING DATA 9519
# file doesnt exist
# SAVING DATA 9969
# file doesnt exist
# SAVING DATA 9729
# file doesnt exist
# SAVING DATA 9819
# file doesnt exist
# SAVING DATA 9609
# file doesnt exist
# SAVING DATA 9459
# file doesnt exist
# SAVING DATA 9759
# file doesnt exist
# SAVING DATA 9849
# file doesnt exist
# SAVING DATA 9999
# file doesnt exist
# SAVING DATA 9909
# file doesnt exist
# SAVING DATA 9879
# file doesnt exist
# SAVING DATA 9669
# file doesnt exist
# SAVING DATA 9249
# file doesnt exist
# SAVING DATA 9939
# file doesnt exist

# %%
plt.figure(figsize=(12,8))
for i in range(10):
    plt.plot(k, pk0_r[i], color=f"C{i%10}", ls='-')
    plt.plot(k, pk2_r[i], color=f"C{i%10}", ls='--')

plt.xscale('log')

# %%
# Change the P(k) model's parameters

# %%
# Increase sig8 to 0.8
model_d.sigma8_z = 0.8

# %%
# Re-load best-fit (unconvolved) P_ell's
tstart = time.time()

k_pole_highk = np.logspace(-3, 0, 1000)
P0_highk_d = d.theory.model.poles(k_pole_highk , 0)
P2_highk_d = d.theory.model.poles(k_pole_highk , 2)
# P4_highk_d = d.theory.model.poles(k_pole_highk , 4)

print("0: ", time.time()-tstart)
# Out:
# 0:  2.8475089073181152

# %%
# Plot k vs. P_l

plt.figure(figsize=(10,7))
plt.loglog(k_pole_highk, np.array(P0_highk_d[:,0]), '-', color = 'royalblue', lw=2.5)
plt.loglog(k_pole_highk, ((b**2+2*b*f/3+(1/5)*f**2)*linpower_z1(k_pole_highk)), '--', color = 'black', lw=2.5)

plt.loglog(k_pole_highk, np.array(P2_highk_d[:,0]), '-', color = 'crimson', lw=2.5)
plt.plot(k_pole_highk, (4*b*f/3+(4/7)*f**2)*linpower_z1(k_pole_highk), '--', color = 'black', lw=2.5)

plt.xlim(1e-3, 0.4)
plt.ylim(1e2, 1e5)
plt.ylabel('$P_l$', fontsize=20)
plt.xlabel('k', fontsize=17)
# Out:
# Text(0.5, 0, 'k')
